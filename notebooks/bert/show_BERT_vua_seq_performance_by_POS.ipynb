# %% [markdown]
# ###Notebook for displaying BERT model's performance on the vua sequence labeling task broken down by POS

# %%
# mount drive
from google.colab import drive
ROOT = '/content/drive'
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# add repo directory to path
import pandas as pd
import os
import sys
from os.path import join 
repo_dir = '/content/drive/MyDrive/Repos/metaphor-detection'
if repo_dir not in sys.path:
    sys.path.append(repo_dir)
print(sys.path)
# Out:
# ['', '/content', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.7/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/Repos/metaphor-detection']

# %%
# %cd drive/MyDrive/Repos/metaphor-detection/
# Out:
# /content/drive/MyDrive/Repos/metaphor-detection

# %%
from core.data.util import get_vua_seq_bert_POS_performance

# %%
pos_df = get_vua_seq_bert_POS_performance()
# Out:
# VUA_seq train nrow: 6323
# VUA_seq test nrow: 2694
# VUA_seq val nrow: 1550

# %%
pos_df
# Out:
#          TP    TN   FP   FN  Precision    Recall        F1
# PUNCT     2  5080    1    1   0.666667  0.666667  0.666667
# ADV     170  3096   53   74   0.762332  0.696721  0.728051
# SYM       0     2    0    0        NaN       NaN       NaN
# DET     396  3657   42   23   0.904110  0.945107  0.924154
# ADP    1515  3467  163  155   0.902861  0.907186  0.905018
# VERB   1419  7555  430  468   0.767442  0.751987  0.759636
# PROPN     8  1868    6   23   0.571429  0.258065  0.355556
# X         0     6    2    0   0.000000       NaN  0.000000
# CCONJ     0  1581    0    0        NaN       NaN       NaN
# ADJ     336  3269  155  205   0.684318  0.621072  0.651163
# PRON      1  3941    8    5   0.111111  0.166667  0.133333
# NUM       0   543    0    0        NaN       NaN       NaN
# NOUN    852  7048  249  439   0.773842  0.659954  0.712375
# INTJ      0   396    0    2        NaN  0.000000  0.000000
# PART    100  1262   52   49   0.657895  0.671141  0.664452

# %%
tbl_5_cols = ["Precision", "Recall", "F1"]
tbl_5_rows = ["VERB", "NOUN", "ADP", "ADJ", "PART"]
pos_df.loc[tbl_5_rows, tbl_5_cols]
# Out:
#       Precision    Recall        F1
# VERB   0.767442  0.751987  0.759636
# NOUN   0.773842  0.659954  0.712375
# ADP    0.902861  0.907186  0.905018
# ADJ    0.684318  0.621072  0.651163
# PART   0.657895  0.671141  0.664452
