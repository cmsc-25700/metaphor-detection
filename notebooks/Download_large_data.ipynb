# %% [markdown]
# ## [metaphor-in-context]
# ## Notebook to assist with downloading large data files into project resources
# You should already have the repo cloned onto your google drive
#
# The data requires about 7gb on your google drive. You need about 10gb to run this notebook, and it takes ~5minutes. Empty your trash once this is done.

# %%
# mount drive
from google.colab import drive
ROOT = '/content/drive'
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install gdown
# !pip install --upgrade --no-cache-dir gdown

# %%
# cd to resources folder
# %cd 'drive/MyDrive/Repos/metaphor-detection/resources/'
# !ls
# Out:
# /content/drive/MyDrive/Repos/metaphor-detection/resources

# %% [markdown]
# ### datasets

# %%
# !gdown 18tBHegty7sWreqj9Fp8zETKloeOpsGHO -O metaphor-in-context.zip
# !unzip metaphor-in-context.zip -d .
# !rm metaphor-in-context.zip

# %%
# !ls
# !rm -rf __MACOSX
# Out:
# __MACOSX  metaphor-in-context

# %%
# !ls
# !ls metaphor-in-context
# Out:
# metaphor-in-context
# corpora  data

# %% [markdown]
# ### glove vectors

# %%
# !mkdir -p glove
# !gdown 1p3Y8d-EXKciFHyhzRfu2XhS3hp7bwWjV -O glove.840B.300d.zip
# !unzip glove.840B.300d.zip -d glove
# !rm glove.840B.300d.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1p3Y8d-EXKciFHyhzRfu2XhS3hp7bwWjV
# To: /content/drive/MyDrive/Repos/metaphor-detection/resources/glove.840B.300d.zip
# 100% 2.18G/2.18G [00:18<00:00, 121MB/s]
# Archive:  glove.840B.300d.zip
#   inflating: glove/glove.840B.300d.txt

# %%
# !ls
# !ls glove
# Out:
# glove  metaphor-in-context
# glove.840B.300d.txt

# %% [markdown]
# ### elmo vectors

# %%
# !gdown 1cq9fm6nfVsVhRxvVfrWAjiVjUJwE5yqc -O elmo.zip
# !unzip elmo.zip -d .
# !rm elmo.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1cq9fm6nfVsVhRxvVfrWAjiVjUJwE5yqc
# To: /content/drive/MyDrive/Repos/metaphor-detection/resources/elmo.zip
# 100% 1.32G/1.32G [00:20<00:00, 65.4MB/s]
# Archive:  elmo.zip
#    creating: ./elmo/
#   inflating: ./elmo/.DS_Store
#    creating: ./__MACOSX/
#    creating: ./__MACOSX/elmo/
#   inflating: ./__MACOSX/elmo/._.DS_Store
#   inflating: ./elmo/VUA_test.hdf5
#   inflating: ./__MACOSX/elmo/._VUA_test.hdf5
#   inflating: ./elmo/TroFi3737.hdf5
#   inflating: ./__MACOSX/elmo/._TroFi3737.hdf5
#   inflating: ./elmo/VUA_train.hdf5
#   inflating: ./__MACOSX/elmo/._VUA_train.hdf5
#   inflating: ./elmo/VUA_val.hdf5
#   inflating: ./__MACOSX/elmo/._VUA_val.hdf5
#   inflating: ./elmo/MOH-X_cleaned.hdf5
#   inflating: ./__MACOSX/elmo/._MOH-X_cleaned.hdf5
#   inflating: ./__MACOSX/._elmo

# %%
# !ls
# !rm -rf __MACOSX
# Out:
# elmo  glove  __MACOSX  metaphor-in-context

# %%
# !ls
# !ls elmo
# Out:
# elmo  glove  metaphor-in-context
# MOH-X_cleaned.hdf5  TroFi3737.hdf5  VUA_test.hdf5  VUA_train.hdf5  VUA_val.hdf5
